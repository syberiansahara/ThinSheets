# %% [markdown]
# # Diploma invariant

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import scipy as sp
from scipy.integrate import quad, simps
import math
from math import atan, sin, cos, acosh, exp, log, cosh, tanh
import MagneticField as MF

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
from numpy.linalg import norm

# %%
def sign(a):
    if a > 0.0:
        return 1.0
    elif a < 0.0:
        return - 1.0
    else:
        return 0.0

# %% [markdown]
# Reloading field module (if necessary)

# %%
reload(MF)
from MagneticField import Field

# %% [markdown]
# Declaring constants

# %%
pi = math.pi
MF.pi = math.pi

delta = 1.0
MF.delta = 1.0

eps = 1e-7 #for energy conservation in Runge-Kutta method

# %% [markdown]
# Obtaining some field constants

# %%
bx0 = Field(0.0, 0.0, 0.0)['bx0']
by0 = Field(0.0, 0.0, 0.0)['by0']
bn = Field(0.0, 0.0, 0.0)['bz']
if Field(0.0, 0.0, 0.0)['fieldtype']:
    fieldtype = 'bell'
else:
    fieldtype = 'constant'

# %% [markdown]
# Defining derivative functions for Runge-Kutta method

# %%
def f(b, a):
        
    q = np.empty((6,))
    q[0] = a[3]
    q[1] = a[4]
    q[2] = a[5]
    q[3] = delta * (b['bz']*a[4] - b['by']*a[5])
    q[4] = delta * (b['bx']*a[5] - b['bz']*a[3])
    q[5] = delta * (b['by']*a[3] - b['bx']*a[4]) 
    
    return q

# %% [markdown]
# Adiabatic Invariant at a fixed point

# %%
def Iz(Vx, x):
    
    zplus = delta * acosh( exp( ( (1.0 - Vx**2)**0.5 + delta*bn*x) / (bx0 * delta**2) ))

    power = ( -(1.0 - Vx**2)**0.5 + delta*bn*x) / (bx0 * delta**2)
    if power < 0.0:
        zminus = 0.0
        integr = quad(lambda z: (1.0 - Vx**2 - ( - delta*bn*x + delta**2 * bx0 * log( cosh( z / delta )))**2  )**0.5, \
                  zminus, zplus) #integration
        return 2.0 * integr[0] 
    else:
        zminus = delta * acosh( exp( power ))
        integr = quad(lambda z: (1.0 - Vx**2 - ( - delta*bn*x + delta**2 * bx0 * log( cosh( z / delta )))**2  )**0.5, \
                  zminus, zplus) #integration
        return integr[0]

# %% [markdown]
# Function returning invariant for all trajectory points

# %%
def Invar(RKt):
    Inv = np.zeros((RKt.shape[0], 1))
    for i in range(RKt.shape[0]):
        Inv[i, 0] = 2.0 * Iz(RKt[i, 3], RKt[i, 0])
    return Inv

# %%
def InvarNum(RKt, ZeroVz):
    Inv = np.zeros((RKt.shape[0], 1))
 
    if len(ZeroVz) % 2 == 0:
        del ZeroVz[-1]
        
    for i in range((len(ZeroVz) - 1) / 2):
        i1 = ZeroVz[2*i]        
        i2 = ZeroVz[2*i + 1]     
        i3 = ZeroVz[2*i + 2]    
        
        y1 = RKt[i1:i2, 5]
        x1 = RKt[i1:i2, 2]
        
        integr1 = simps(y1, x1, even='first')
        int1 = integr1
        
        y2 = RKt[i2:i3, 5]
        x2 = RKt[i2:i3, 2]
        
        integr2 = simps(y2, x2, even='first')
        int2 = integr2
        
        Inv[i1:i3, 0] = int1 + int2
        
    Inv[0:ZeroVz[0], 0] = Inv[ZeroVz[0]+2, 0]
    Inv[ZeroVz[-2]:RKt.shape[0], 0] = Inv[ZeroVz[-1]-2, 0]
    return Inv

# %% [markdown]
# Function returning array with invariant surges

# %%
def SurgeFunction(ZeroIndices, ZeroVz, Invariant, RKt):
    result = []
    if len(ZeroIndices) == 0:
        return result
    else:
        zi1 = ZeroIndices[0]        
        if len(ZeroIndices) == 1:
            zi2 = Invariant.shape[0] - 1
        else:                        
            for k in range(1, len(ZeroIndices)):
                        
                Serpentine = True
                
                if len([ind for ind in ZeroVz if ind > ZeroIndices[k-1] and ind <= ZeroIndices[k]]) >= 2:
                    Serpentine = False
                
                if not Serpentine:
                    break
                
            if Serpentine:
                zi2 = ZeroIndices[k]
            elif k == 1:
                zi2 = ZeroIndices[1]
            else:
                zi2 = ZeroIndices[k-1]
            
        mean1 = np.mean(Invariant[0 : zi1]) 
        mean2 = np.mean(Invariant[zi1 : zi2])
        
        result.append(mean2 - mean1)
        
        zi1zi2 = []
        zi1zi2.append(zi1)
        zi1zi2.append(zi2)
               
    
        return result, zi1zi2

# %%
def InitialConditions(a02, phase, pitch): #angle setting for Invariant calculations
        
    b = Field(0, 0, a02)

    if b['bx'] == 0 and b['by'] == 0:
        alpha = (pi / 2)
    else:
        alpha = atan(b['bz'] / (b['bx']**2 + b['by']**2)**0.5)  

    if b['bx'] == 0:
        gamma = (pi / 2) * sign(b['by'])
    elif b['bx'] > 0:
        gamma = atan(b['by'] / b['bx']) 
    else: 
        gamma = pi + atan(b['by'] / b['bx'])
        
    phi = (2.0 * pi) * (phase * 1.0) / maxphase
    
    theta = (1.4) * (pitch * 1.0) / maxpitch
    
    
    
    if a02 > 0.0:
        theta = pi - theta #so that the particle moves towards the neutral sheet
    
    print 'phi =', round(phi, 3), ', theta =', round(theta, 3)
    
    a03 = (-sin(theta) * sin(alpha) * cos(phi) + cos(theta) * cos(alpha)) * cos(gamma) - \
        (sin(theta) * sin(phi)) * sin(gamma)
    a04 = (-sin(theta) * sin(alpha) * cos(phi) + cos(theta) * cos(alpha)) * sin(gamma) + \
        (sin(theta) * sin(phi)) * cos(gamma)
    a05 = cos(theta) * sin(alpha) + sin(theta) * cos(alpha) * cos(phi)

        
    a0 = np.array([a00, a01, a02, a03, a04, a05])
    
    return a0

# %% [markdown]
# Defining Runge-Kutta method

# %%
def RK4_Inv(f, a0):
    Cy = a0[4]  + delta*bn*a0[0] - delta**2 * bx0 * log( cosh( a0[2] / delta ))
    a0[0] = a0[0] - Cy / (bn*delta) #shift of coordinates    
    
    
    RK = a0.reshape((1, 6)) #trajectory array
    times = [0.0] #array with times
    Poinc = np.zeros((pcountmax, 2)) #array with found poincare points for the current particle
    ZeroIndices = [] #indices of poincare points in trajectory array
    ZeroVz = [] #indices of null Vz speed
    
    en0 = (a0[3]**2 + a0[4]**2 + a0[5]**2)**0.5 #initial energy equals 1.0
    
    t = 0.0 #initial time
    i = 0 #current trajectory point
    idiv = 0 #number of times division dt/2 was used        
    pcount = 0 #number of found points suitable for Poincare section
    toofar = False #whether the particle is too far from the layer
    
    
    OldRK = a0    
       
    while t < tfinal:
        
        ##==============Runge-Kutta step===============
        
        dt = dt0
        for s in range(100):  
            
            b = Field(OldRK[0], OldRK[1], OldRK[2])
            k1 = dt * f(b, OldRK)
            
            b = Field(OldRK[0] + 0.5*k1[0], OldRK[1] + 0.5*k1[1], OldRK[2] + 0.5*k1[2])
            k2 = dt * f(b, OldRK + 0.5*k1)
            
            b = Field(OldRK[0] + 0.5*k2[0], OldRK[1] + 0.5*k2[1], OldRK[2] + 0.5*k2[2])
            k3 = dt * f(b, OldRK + 0.5*k2) 
            
            b = Field(OldRK[0] + k3[0], OldRK[1] + k3[1], OldRK[2] + k3[2])
            k4 = dt * f(b, OldRK + k3) 
            
            NewRK = OldRK + ( k1 + 2.0 * ( k2 + k3 ) + k4 ) / 6.0
            en = (NewRK[3]**2 + NewRK[4]**2 + NewRK[5]**2)**0.5
            
            if abs(en - en0) < eps: #energy conservation control
                break  
            dt = dt / 2.0
            idiv +=1
            
        RK = np.vstack((RK, NewRK)) #adding new line to trajectory array
        t +=dt
        times.append(t)
        
        
        if OldRK[5] * NewRK[5] < 0: #Vz speed sign change condition
            ZeroVz.append(i)
            
        ##=================== Poincare==================
        
        if OldRK[2] * NewRK[2] < 0: #z coordinate sign change condition
            
            ZeroIndices.append(i)
            
            if pcount < pcountmax:        
                                    
                #linear approximation of bn*delta*(x)
                Poinc[pcount, 0] = bn * delta * (OldRK[0] + OldRK[2] * (NewRK[0] - OldRK[0]) / \
                                                 (OldRK[2] - NewRK[2]))
                
                #linear approximation of Vx
                Poinc[pcount, 1] = OldRK[3] + OldRK[2] * (NewRK[3] - OldRK[3]) / (OldRK[2] - NewRK[2])
                                    
                pcount +=1
        
        if len(ZeroIndices) >= 2 and ( len([ind for ind in ZeroVz if ind > ZeroIndices[-1]]) >= 2 \
                                      or len([ind for ind in ZeroVz if ind > ZeroIndices[-2] and ind <= ZeroIndices[-1]]) >= 2):
            break
        
        #if len(ZeroIndices) >= 2 and len([ind for ind in ZeroVz if ind > ZeroIndices[-1]]) >= 2:
            #break
            
        #if len(ZeroIndices) >= 2 and len([ind for ind in ZeroVz if ind > ZeroIndices[-2] and ind <= ZeroIndices[-1]]) >= 2:
            #break            
        
        if pcount == pcountmax:
            break
        
        ##==============================================

        if abs(NewRK[2] / a02) > 2.0: #particle too far from the layer
            toofar = True
            break
        
        OldRK = NewRK
        i +=1
    
    length = len(times)
    times = np.asarray(times).reshape((length, 1))
    RKt = np.hstack((RK, times)) #array with Runge-Kutta results and times
       
    
    print 'p =', p
    print 'Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) =', round(a0[0], 5), ',', round(a0[1], 5), ',', round(a0[2], 5), \
          ',', round(a0[3], 5), ',', round(a0[4], 5), ',', round(a0[5], 5)
    print 'Particle too far from the layer =', toofar
    print 'Initial energy =', en0, ', final energy =', en
    print 'Time =', t, ', Total calculated points =', i+1
    print 'Total Poincare points =', len(ZeroIndices), '/', pcountmax
    #print 'Number of times division dt/2 was used =', idiv
    print '\n'
   
    return RKt, Poinc, ZeroIndices, ZeroVz

# %% [markdown]
# Setting

# %%
dt0 = 0.01
tfinal = 800.0
pcountmax = 19 # maximum Poincare points
maxphase = 10 #number of different pitch angles
maxpitch = 11 #number of different phases
pmax = maxphase * (maxpitch - 1)

a00 = 0.0
a01 = 0.0

# %% [markdown]
# ## One particle

# %%
root = r'C:\Users\syber\Syber Python\Diploma\Constant\by=0.0bx\bn=0.02bx'

# %%
folder = r'North\p=0'
a02 = 5.0
    
logfile1 = open(r'%s\%s\parameters.txt' %(root, folder), 'w')
logfile1.write('Field type = %s\nbx0 = %g\nby0 = %g\nbn = %g\n\ndelta = %g\ndt0 = %g\ntfinal = %g\npcountmax = %g\n\n' \
              %(fieldtype, bx0, by0, bn, delta, dt0, tfinal, pcountmax))
logfile1.write('maxphase = %g\nmaxpitch = %g\n' \
              %(maxphase, maxpitch))
logfile1.write('number of particles = %g\n\n' %(pmax)) 
logfile1.close()  

phase = 0
pitch = 1

p = phase * (maxpitch - 1) + pitch - 1

a0 = InitialConditions(a02, phase, pitch)

RKt, Poinc, ZeroIndices, ZeroVz = RK4_Inv(f, a0)

Invariant = Invar(RKt)
InvariantNum = InvarNum(RKt, ZeroVz)
Surge, zi1zi2 = SurgeFunction(ZeroIndices, ZeroVz, Invariant, RKt)  
SurgeNum, _ = SurgeFunction(ZeroIndices, ZeroVz, InvariantNum, RKt)

np.savetxt(r'%s\%s\Trajectory_%d.txt' %(root, folder, p), \
                   RKt, ['%.4g','%.4g','%.4g','%.4g','%.4g','%.4g','%g',], delimiter=',')  
np.savetxt(r'%s\%s\Poinc_%d.txt' %(root, folder, p), \
                   Poinc, '%.3g', delimiter=',')
np.savetxt(r'%s\%s\Invariant_%d.txt' %(root, folder, p), \
                   Invariant, '%.4g', delimiter=',')
np.savetxt(r'%s\%s\InvariantNum_%d.txt' %(root, folder, p), \
                   InvariantNum, '%.4g', delimiter=',')

indicesfile0 = open(r'%s\%s\ZeroVz_%d.txt' %(root, folder, p), 'w')
for i in ZeroVz: 
    indicesfile0.write('%s\n' %i)    
indicesfile0.close()     
    
indicesfile = open(r'%s\%s\ZeroIndices_%d.txt' %(root, folder, p), 'w')
for i in ZeroIndices: 
    indicesfile.write('%s\n' %i)    
indicesfile.close()

indfile = open(r'%s\%s\zi1zi2_%d.txt' %(root, folder, p), 'w')
for i in zi1zi2: 
    indfile.write('%s\n' %i)    
indfile.close()

Surge = np.array(Surge)
SurgeNum = np.array(SurgeNum)
print 'Surges: ', Surge[0], ',', SurgeNum[0]

np.savetxt(r'%s\%s\Surge_%d.txt' %(root, folder, p), Surge, '%g', delimiter=',')
np.savetxt(r'%s\%s\SurgeNum_%d.txt' %(root, folder, p), SurgeNum, '%g', delimiter=',')

# %%
dt0 = 0.01
tfinal = 900.0
pcountmax = 19 # maximum Poincare points
maxphase = 10 #number of different pitch angles
maxpitch = 11 #number of different phases
pmax = maxphase * (maxpitch - 1)

a00 = 0.0
a01 = 0.0

# %%
reload(MF)
from MagneticField import Field

# %%
bx0 = Field(0.0, 0.0, 0.0)['bx0']
by0 = Field(0.0, 0.0, 0.0)['by0']
bn = Field(0.0, 0.0, 0.0)['bz']
if Field(0.0, 0.0, 0.0)['fieldtype']:
    fieldtype = 'bell'
else:
    fieldtype = 'constant'

# %% [markdown]
# ## Multiple particles (with invariant)

# %%
root = r'C:\Users\syber\Syber Python\Diploma\Constant\by=0.75bx\bn=0.10bx'

# %%
folder = r'North'
a02 = 5
thebn = 0.10

logfile1 = open(r'%s\%s\parameters.txt' %(root, folder), 'w')
logfile1.write('Field type = %s\nbx0 = %g\nby0 = %g\nbn = %g\n\ndelta = %g\ndt0 = %g\ntfinal = %g\npcountmax = %g\n\n' \
              %(fieldtype, bx0, by0, bn, delta, dt0, tfinal, pcountmax))
logfile1.write('maxphase = %g\nmaxpitch = %g\n' \
              %(maxphase, maxpitch))
logfile1.write('number of particles = %g\n\n' %(pmax)) 
logfile1.close() 

Poincare = np.zeros((pcountmax, 2*pmax))

AllSurges = []
AllSurgesNum = []

p = -1

for phase in range(maxphase):
    for pitch in range(1, maxpitch):
        p +=1 
        
        print 'phase =', phase, ', pitch =', pitch
        a0 = InitialConditions(a02, phase, pitch)        
        
        RKt, Poinc, ZeroIndices, ZeroVz = RK4_Inv(f, a0)
        
        Invariant = Invar(RKt)
        InvariantNum = InvarNum(RKt, ZeroVz)
        
        Surge, zi1zi2 = SurgeFunction(ZeroIndices, ZeroVz, Invariant, RKt)
        SurgeNum, _ = SurgeFunction(ZeroIndices, ZeroVz, InvariantNum, RKt)  
        
        AllSurges.extend(Surge)
        AllSurgesNum.extend(SurgeNum)
        
        Poincare[:, 2*p] = Poinc[:, 0]
        Poincare[:, 2*p + 1] = Poinc[:, 1] 
           
        #np.savetxt(r'%s\%s\Trajectory_%d.txt' %(root, folder, p), \
                   #RKt, ['%.4g','%.4g','%.4g','%.4g','%.4g','%.4g','%g',], delimiter=',') 
        
        #indicesfile0 = open(r'%s\%s\ZeroVz_%d.txt' %(root, folder, p), 'w')
        #for i in ZeroVz: 
            #indicesfile0.write('%s\n' %i)    
        #indicesfile0.close()   
        
        #indicesfile = open(r'%s\%s\ZeroIndices_%d.txt' %(root, folder, p), 'w')
        #for i in ZeroIndices: 
            #indicesfile.write('%s\n' %i)    
        #indicesfile.close() 
        
        #indfile = open(r'%s\%s\zi1zi2_%d.txt' %(root, folder, p), 'w')
        #for i in zi1zi2: 
            #indfile.write('%s\n' %i)    
        #indfile.close()
        
        #np.savetxt(r'%s\%s\Invariant_%d.txt' %(root, folder, p), \
                   #Invariant, '%.4g', delimiter=',') 
        
        #np.savetxt(r'%s\%s\InvariantNum_%d.txt' %(root, folder, p), \
                   #InvariantNum, '%.4g', delimiter=',')
        
        #np.savetxt(r'%s\%s\Poinc_%d.txt' %(root, folder, p), \
                   #Poinc, '%.3g', delimiter=',')
            
            
            
AllSurges = np.array(AllSurges)
AllSurgesNum = np.array(AllSurgesNum)

print 'Surges. Mean: ', np.mean(AllSurges), '. Mean of **2:', np.mean(AllSurges**2)
print 'Surges Numerical. Mean: ', np.mean(AllSurgesNum), '. Mean of **2:', np.mean(AllSurgesNum**2)
    
np.savetxt(r'%s\%s\Poincare.txt' %(root, folder), Poincare, '%.3g', delimiter=',')
np.savetxt(r'%s\%s\AllSurges.txt' %(root, folder), AllSurges, '%g', delimiter=',')
np.savetxt(r'%s\%s\AllSurgesNum.txt' %(root, folder), AllSurgesNum, '%g', delimiter=',')

logfile2 = open(r'%s\%s\means.txt' %(root, folder), 'w')
logfile2.write('%g,%g,%g,%g,%g' %(thebn, np.mean(AllSurges), np.mean(AllSurges**2), log(thebn), log(np.mean(AllSurges**2))))
logfile2.close()

logfile3 = open(r'%s\%s\meansnum.txt' %(root, folder), 'w')
logfile3.write('%g,%g,%g,%g,%g' %(thebn, np.mean(AllSurgesNum), np.mean(AllSurgesNum**2), log(thebn), log(np.mean(AllSurgesNum**2))))
logfile3.close()

logfile4 = open(r'%s\%s\log.txt' %(root, folder), 'w')
logfile4.close()
# Out:
# phase = 0 , pitch = 1
# phi = 0.0 , theta = 3.014
# p = 0
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 50.58492 , 0.0 , 5.0 , -0.79907 , -0.59936 , 0.04742
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.9999999998
# Time = 335.14 , Total calculated points = 33514
# Total Poincare points = 1 / 19
#
#
# phase = 0 , pitch = 2
# phi = 0.0 , theta = 2.887
# p = 1
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 50.47884 , 0.0 , 5.0 , -0.7878 , -0.5909 , 0.17382
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999848
# Time = 278.28 , Total calculated points = 27828
# Total Poincare points = 1 / 19
#
#
# phase = 0 , pitch = 3
# phi = 0.0 , theta = 2.76
# p = 2
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 50.25289 , 0.0 , 5.0 , -0.76377 , -0.57288 , 0.29741
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999981
# Time = 73.31 , Total calculated points = 7331
# Total Poincare points = 3 / 19
#
#
# phase = 0 , pitch = 4
# phi = 0.0 , theta = 2.633
# p = 3
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 49.91073 , 0.0 , 5.0 , -0.7274 , -0.5456 , 0.41619
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999892
# Time = 238.43 , Total calculated points = 23843
# Total Poincare points = 1 / 19
#
#
# phase = 0 , pitch = 5
# phi = 0.0 , theta = 2.505
# p = 4
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 49.4579 , 0.0 , 5.0 , -0.67925 , -0.50949 , 0.52824
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999979
# Time = 80.5 , Total calculated points = 8050
# Total Poincare points = 3 / 19
#
#
# phase = 0 , pitch = 6
# phi = 0.0 , theta = 2.378
# p = 5
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 48.90172 , 0.0 , 5.0 , -0.62012 , -0.46513 , 0.63174
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999981
# Time = 97.16 , Total calculated points = 9716
# Total Poincare points = 5 / 19
#
#
# phase = 0 , pitch = 7
# phi = 0.0 , theta = 2.251
# p = 6
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 48.25118 , 0.0 , 5.0 , -0.55096 , -0.41326 , 0.72503
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999928
# Time = 226.31 , Total calculated points = 22631
# Total Poincare points = 1 / 19
#
#
# phase = 0 , pitch = 8
# phi = 0.0 , theta = 2.123
# p = 7
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 47.51682 , 0.0 , 5.0 , -0.47288 , -0.35469 , 0.80658
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999946
# Time = 226.01 , Total calculated points = 22601
# Total Poincare points = 1 / 19
#
#
# phase = 0 , pitch = 9
# phi = 0.0 , theta = 1.996
# p = 8
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 46.7105 , 0.0 , 5.0 , -0.38716 , -0.29039 , 0.87509
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999972
# Time = 225.75 , Total calculated points = 22575
# Total Poincare points = 1 / 19
#
#
# phase = 0 , pitch = 10
# phi = 0.0 , theta = 1.869
# p = 9
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 45.84528 , 0.0 , 5.0 , -0.29517 , -0.2214 , 0.92944
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999953
# Time = 263.71 , Total calculated points = 26371
# Total Poincare points = 1 / 19
#
#
# phase = 1 , pitch = 1
# phi = 0.628 , theta = 3.014
# p = 10
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 49.82194 , 0.0 , 5.0 , -0.84229 , -0.53852 , 0.02326
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999795
# Time = 340.63 , Total calculated points = 34063
# Total Poincare points = 1 / 19
#
#
# phase = 1 , pitch = 2
# phi = 0.628 , theta = 2.887
# p = 11
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 48.96522 , 0.0 , 5.0 , -0.87354 , -0.4702 , 0.12589
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999848
# Time = 276.58 , Total calculated points = 27658
# Total Poincare points = 1 / 19
#
#
# phase = 1 , pitch = 3
# phi = 0.628 , theta = 2.76
# p = 12
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 48.01313 , 0.0 , 5.0 , -0.89065 , -0.39427 , 0.22648
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999892
# Time = 231.86 , Total calculated points = 23186
# Total Poincare points = 1 / 19
#
#
# phase = 1 , pitch = 4
# phi = 0.628 , theta = 2.633
# p = 13
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 46.98105 , 0.0 , 5.0 , -0.89335 , -0.31197 , 0.32341
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999865
# Time = 260.03 , Total calculated points = 26003
# Total Poincare points = 1 / 19
#
#
# phase = 1 , pitch = 5
# phi = 0.628 , theta = 2.505
# p = 14
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 45.88569 , 0.0 , 5.0 , -0.88161 , -0.22462 , 0.41511
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999881
# Time = 250.83 , Total calculated points = 25083
# Total Poincare points = 1 / 19
#
#
# phase = 1 , pitch = 6
# phi = 0.628 , theta = 2.378
# p = 15
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 44.74477 , 0.0 , 5.0 , -0.8556 , -0.13364 , 0.50009
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999985
# Time = 81.96 , Total calculated points = 8196
# Total Poincare points = 3 / 19
#
#
# phase = 1 , pitch = 7
# phi = 0.628 , theta = 2.251
# p = 16
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 43.57674 , 0.0 , 5.0 , -0.81575 , -0.04049 , 0.57698
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999964
# Time = 146.83 , Total calculated points = 14683
# Total Poincare points = 19 / 19
#
#
# phase = 1 , pitch = 8
# phi = 0.628 , theta = 2.123
# p = 17
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 42.40049 , 0.0 , 5.0 , -0.76271 , 0.05331 , 0.64454
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999976
# Time = 199.43 , Total calculated points = 19943
# Total Poincare points = 1 / 19
#
#
# phase = 1 , pitch = 9
# phi = 0.628 , theta = 1.996
# p = 18
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 41.23506 , 0.0 , 5.0 , -0.69732 , 0.14625 , 0.70168
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.99999999992
# Time = 246.99 , Total calculated points = 24699
# Total Poincare points = 1 / 19
#
#
# phase = 1 , pitch = 10
# phi = 0.628 , theta = 1.869
# p = 19
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 40.09929 , 0.0 , 5.0 , -0.62066 , 0.23682 , 0.74746
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999956
# Time = 149.22 , Total calculated points = 14922
# Total Poincare points = 5 / 19
#
#
# phase = 2 , pitch = 1
# phi = 1.257 , theta = 3.014
# p = 20
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 49.3213 , 0.0 , 5.0 , -0.86591 , -0.49859 , -0.04001
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999795
# Time = 339.87 , Total calculated points = 33987
# Total Poincare points = 1 / 19
#
#
# phase = 2 , pitch = 2
# phi = 1.257 , theta = 2.887
# p = 21
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 47.97204 , 0.0 , 5.0 , -0.92039 , -0.391 , 0.00038
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999827
# Time = 300.99 , Total calculated points = 30099
# Total Poincare points = 1 / 19
#
#
# phase = 2 , pitch = 3
# phi = 1.257 , theta = 2.76
# p = 22
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 46.54347 , 0.0 , 5.0 , -0.95998 , -0.27707 , 0.04077
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999867
# Time = 256.37 , Total calculated points = 25637
# Total Poincare points = 1 / 19
#
#
# phase = 2 , pitch = 4
# phi = 1.257 , theta = 2.633
# p = 23
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 45.0587 , 0.0 , 5.0 , -0.98405 , -0.15867 , 0.08049
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999915
# Time = 211.76 , Total calculated points = 21176
# Total Poincare points = 1 / 19
#
#
# phase = 2 , pitch = 5
# phi = 1.257 , theta = 2.505
# p = 24
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 43.54173 , 0.0 , 5.0 , -0.99219 , -0.0377 , 0.11892
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999928
# Time = 201.49 , Total calculated points = 20149
# Total Poincare points = 1 / 19
#
#
# phase = 2 , pitch = 6
# phi = 1.257 , theta = 2.378
# p = 25
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 42.01712 , 0.0 , 5.0 , -0.98428 , 0.08388 , 0.15542
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999926
# Time = 212.01 , Total calculated points = 21201
# Total Poincare points = 1 / 19
#
#
# phase = 2 , pitch = 7
# phi = 1.257 , theta = 2.251
# p = 26
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 40.50953 , 0.0 , 5.0 , -0.96045 , 0.2041 , 0.1894
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999887
# Time = 252.1 , Total calculated points = 25210
# Total Poincare points = 1 / 19
#
#
# phase = 2 , pitch = 8
# phi = 1.257 , theta = 2.123
# p = 27
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 39.04334 , 0.0 , 5.0 , -0.92109 , 0.32103 , 0.22032
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999974
# Time = 193.09 , Total calculated points = 19309
# Total Poincare points = 1 / 19
#
#
# phase = 2 , pitch = 9
# phi = 1.257 , theta = 1.996
# p = 28
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 37.64226 , 0.0 , 5.0 , -0.86682 , 0.43275 , 0.24768
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999989
# Time = 199.36 , Total calculated points = 19936
# Total Poincare points = 1 / 19
#
#
# phase = 2 , pitch = 10
# phi = 1.257 , theta = 1.869
# p = 29
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 36.32898 , 0.0 , 5.0 , -0.79853 , 0.53748 , 0.27103
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999979
# Time = 221.86 , Total calculated points = 22186
# Total Poincare points = 1 / 19
#
#
# phase = 3 , pitch = 1
# phi = 1.885 , theta = 3.014
# p = 30
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 49.27423 , 0.0 , 5.0 , -0.86091 , -0.49484 , -0.1182
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999799
# Time = 333.6 , Total calculated points = 33360
# Total Poincare points = 1 / 19
#
#
# phase = 3 , pitch = 2
# phi = 1.885 , theta = 2.887
# p = 31
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 47.87866 , 0.0 , 5.0 , -0.91046 , -0.38355 , -0.15474
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999849
# Time = 275.17 , Total calculated points = 27517
# Total Poincare points = 1 / 19
#
#
# phase = 3 , pitch = 3
# phi = 1.885 , theta = 2.76
# p = 32
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 46.40528 , 0.0 , 5.0 , -0.94529 , -0.26605 , -0.18878
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999885
# Time = 236.82 , Total calculated points = 23682
# Total Poincare points = 1 / 19
#
#
# phase = 3 , pitch = 4
# phi = 1.885 , theta = 2.633
# p = 33
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 44.87794 , 0.0 , 5.0 , -0.96483 , -0.14426 , -0.21977
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999922
# Time = 205.18 , Total calculated points = 20518
# Total Poincare points = 1 / 19
#
#
# phase = 3 , pitch = 5
# phi = 1.885 , theta = 2.505
# p = 34
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 43.32134 , 0.0 , 5.0 , -0.96876 , -0.02012 , -0.2472
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999987
# Time = 73.51 , Total calculated points = 7351
# Total Poincare points = 3 / 19
#
#
# phase = 3 , pitch = 6
# phi = 1.885 , theta = 2.378
# p = 35
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 41.76065 , 0.0 , 5.0 , -0.95701 , 0.10433 , -0.27063
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999943
# Time = 198.38 , Total calculated points = 19838
# Total Poincare points = 1 / 19
#
#
# phase = 3 , pitch = 7
# phi = 1.885 , theta = 2.251
# p = 36
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 40.22113 , 0.0 , 5.0 , -0.92979 , 0.2271 , -0.28968
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999925
# Time = 218.51 , Total calculated points = 21851
# Total Poincare points = 1 / 19
#
#
# phase = 3 , pitch = 8
# phi = 1.885 , theta = 2.123
# p = 37
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 38.72767 , 0.0 , 5.0 , -0.88753 , 0.3462 , -0.30405
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999982
# Time = 186.63 , Total calculated points = 18663
# Total Poincare points = 1 / 19
#
#
# phase = 3 , pitch = 9
# phi = 1.885 , theta = 1.996
# p = 38
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 37.30445 , 0.0 , 5.0 , -0.8309 , 0.45969 , -0.31349
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999988
# Time = 195.43 , Total calculated points = 19543
# Total Poincare points = 1 / 19
#
#
# phase = 3 , pitch = 10
# phi = 1.885 , theta = 1.869
# p = 39
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 35.97447 , 0.0 , 5.0 , -0.76084 , 0.56575 , -0.31787
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999974
# Time = 222.41 , Total calculated points = 22241
# Total Poincare points = 1 / 19
#
#
# phase = 4 , pitch = 1
# phi = 2.513 , theta = 3.014
# p = 40
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 49.6987 , 0.0 , 5.0 , -0.82919 , -0.52869 , -0.18147
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999704
# Time = 461.33 , Total calculated points = 46133
# Total Poincare points = 1 / 19
#
#
# phase = 4 , pitch = 2
# phi = 2.513 , theta = 2.887
# p = 41
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 48.72074 , 0.0 , 5.0 , -0.84754 , -0.4507 , -0.28025
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999794
# Time = 340.67 , Total calculated points = 34067
# Total Poincare points = 1 / 19
#
#
# phase = 4 , pitch = 3
# phi = 2.513 , theta = 2.76
# p = 42
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 47.65135 , 0.0 , 5.0 , -0.85219 , -0.36542 , -0.37449
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.99999999996
# Time = 140.94 , Total calculated points = 14094
# Total Poincare points = 2 / 19
#
#
# phase = 4 , pitch = 4
# phi = 2.513 , theta = 2.633
# p = 43
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 46.50783 , 0.0 , 5.0 , -0.84304 , -0.27423 , -0.46268
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999733
# Time = 427.11 , Total calculated points = 42711
# Total Poincare points = 1 / 19
#
#
# phase = 4 , pitch = 5
# phi = 2.513 , theta = 2.505
# p = 44
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 45.30869 , 0.0 , 5.0 , -0.82026 , -0.17861 , -0.54339
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999939
# Time = 197.88 , Total calculated points = 19788
# Total Poincare points = 1 / 19
#
#
# phase = 4 , pitch = 6
# phi = 2.513 , theta = 2.378
# p = 45
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 44.07332 , 0.0 , 5.0 , -0.78421 , -0.08009 , -0.6153
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999893
# Time = 243.19 , Total calculated points = 24319
# Total Poincare points = 1 / 19
#
#
# phase = 4 , pitch = 7
# phi = 2.513 , theta = 2.251
# p = 46
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 42.8217 , 0.0 , 5.0 , -0.73548 , 0.01972 , -0.67726
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999921
# Time = 224.57 , Total calculated points = 22457
# Total Poincare points = 1 / 19
#
#
# phase = 4 , pitch = 8
# phi = 2.513 , theta = 2.123
# p = 47
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 41.57408 , 0.0 , 5.0 , -0.67484 , 0.11921 , -0.72827
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999978
# Time = 193.77 , Total calculated points = 19377
# Total Poincare points = 1 / 19
#
#
# phase = 4 , pitch = 9
# phi = 2.513 , theta = 1.996
# p = 48
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 40.35064 , 0.0 , 5.0 , -0.60329 , 0.21677 , -0.76749
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.99999999997
# Time = 216.9 , Total calculated points = 21690
# Total Poincare points = 1 / 19
#
#
# phase = 4 , pitch = 10
# phi = 2.513 , theta = 1.869
# p = 49
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 39.17117 , 0.0 , 5.0 , -0.52199 , 0.31083 , -0.7943
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999928
# Time = 263.37 , Total calculated points = 26337
# Total Poincare points = 1 / 19
#
#
# phase = 5 , pitch = 1
# phi = 3.142 , theta = 3.014
# p = 50
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 50.43258 , 0.0 , 5.0 , -0.78288 , -0.58721 , -0.20563
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999889
# Time = 261.39 , Total calculated points = 26139
# Total Poincare points = 2 / 19
#
#
# phase = 5 , pitch = 2
# phi = 3.142 , theta = 2.887
# p = 51
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 50.17663 , 0.0 , 5.0 , -0.75567 , -0.5668 , -0.32818
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999627
# Time = 571.29 , Total calculated points = 57129
# Total Poincare points = 1 / 19
#
#
# phase = 5 , pitch = 3
# phi = 3.142 , theta = 2.76
# p = 52
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 49.80571 , 0.0 , 5.0 , -0.71623 , -0.53722 , -0.44543
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999879
# Time = 248.11 , Total calculated points = 24811
# Total Poincare points = 1 / 19
#
#
# phase = 5 , pitch = 4
# phi = 3.142 , theta = 2.633
# p = 53
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 49.32581 , 0.0 , 5.0 , -0.66521 , -0.49895 , -0.55547
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999956
# Time = 146.97 , Total calculated points = 14697
# Total Poincare points = 2 / 19
#
#
# phase = 5 , pitch = 5
# phi = 3.142 , theta = 2.505
# p = 54
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 48.74469 , 0.0 , 5.0 , -0.60343 , -0.45261 , -0.65652
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999933
# Time = 209.39 , Total calculated points = 20939
# Total Poincare points = 1 / 19
#
#
# phase = 5 , pitch = 6
# phi = 3.142 , theta = 2.378
# p = 55
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 48.07176 , 0.0 , 5.0 , -0.53188 , -0.39895 , -0.74696
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.99999999994
# Time = 209.56 , Total calculated points = 20956
# Total Poincare points = 1 / 19
#
#
# phase = 5 , pitch = 7
# phi = 3.142 , theta = 2.251
# p = 56
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 47.3179 , 0.0 , 5.0 , -0.45173 , -0.33883 , -0.82531
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999971
# Time = 197.78 , Total calculated points = 19778
# Total Poincare points = 1 / 19
#
#
# phase = 5 , pitch = 8
# phi = 3.142 , theta = 2.123
# p = 57
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 46.49532 , 0.0 , 5.0 , -0.36428 , -0.27323 , -0.89031
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999973
# Time = 205.51 , Total calculated points = 20551
# Total Poincare points = 1 / 19
#
#
# phase = 5 , pitch = 9
# phi = 3.142 , theta = 1.996
# p = 58
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 45.6173 , 0.0 , 5.0 , -0.27093 , -0.20322 , -0.9409
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999899
# Time = 275.71 , Total calculated points = 27571
# Total Poincare points = 1 / 19
#
#
# phase = 5 , pitch = 10
# phi = 3.142 , theta = 1.869
# p = 59
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 44.69806 , 0.0 , 5.0 , -0.1732 , -0.12991 , -0.97628
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999881
# Time = 308.7 , Total calculated points = 30870
# Total Poincare points = 1 / 19
#
#
# phase = 6 , pitch = 1
# phi = 3.77 , theta = 3.014
# p = 60
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 51.19556 , 0.0 , 5.0 , -0.73966 , -0.64806 , -0.18147
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999709
# Time = 456.97 , Total calculated points = 45697
# Total Poincare points = 1 / 19
#
#
# phase = 6 , pitch = 2
# phi = 3.77 , theta = 2.887
# p = 61
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 51.69025 , 0.0 , 5.0 , -0.66992 , -0.6875 , -0.28025
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999855
# Time = 273.46 , Total calculated points = 27346
# Total Poincare points = 1 / 19
#
#
# phase = 6 , pitch = 3
# phi = 3.77 , theta = 2.76
# p = 62
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 52.04547 , 0.0 , 5.0 , -0.58935 , -0.71583 , -0.37449
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999956
# Time = 153.48 , Total calculated points = 15348
# Total Poincare points = 2 / 19
#
#
# phase = 6 , pitch = 4
# phi = 3.77 , theta = 2.633
# p = 63
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 52.25549 , 0.0 , 5.0 , -0.49925 , -0.73258 , -0.46268
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.99999999992
# Time = 215.89 , Total calculated points = 21589
# Total Poincare points = 1 / 19
#
#
# phase = 6 , pitch = 5
# phi = 3.77 , theta = 2.505
# p = 64
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 52.3169 , 0.0 , 5.0 , -0.40107 , -0.73748 , -0.54339
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999928
# Time = 215.38 , Total calculated points = 21538
# Total Poincare points = 1 / 19
#
#
# phase = 6 , pitch = 6
# phi = 3.77 , theta = 2.378
# p = 65
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 52.22871 , 0.0 , 5.0 , -0.2964 , -0.73044 , -0.6153
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999957
# Time = 202.74 , Total calculated points = 20274
# Total Poincare points = 1 / 19
#
#
# phase = 6 , pitch = 7
# phi = 3.77 , theta = 2.251
# p = 66
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 51.99235 , 0.0 , 5.0 , -0.18694 , -0.7116 , -0.67726
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999934
# Time = 228.49 , Total calculated points = 22849
# Total Poincare points = 1 / 19
#
#
# phase = 6 , pitch = 8
# phi = 3.77 , theta = 2.123
# p = 67
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 51.61164 , 0.0 , 5.0 , -0.07445 , -0.68124 , -0.72827
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999968
# Time = 217.32 , Total calculated points = 21732
# Total Poincare points = 1 / 19
#
#
# phase = 6 , pitch = 9
# phi = 3.77 , theta = 1.996
# p = 68
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 51.09274 , 0.0 , 5.0 , 0.03924 , -0.63986 , -0.76749
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999961
# Time = 242.68 , Total calculated points = 24268
# Total Poincare points = 1 / 19
#
#
# phase = 6 , pitch = 10
# phi = 3.77 , theta = 1.869
# p = 69
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 50.44405 , 0.0 , 5.0 , 0.15229 , -0.58813 , -0.7943
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999937
# Time = 185.1 , Total calculated points = 18510
# Total Poincare points = 3 / 19
#
#
# phase = 7 , pitch = 1
# phi = 4.398 , theta = 3.014
# p = 70
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 51.6962 , 0.0 , 5.0 , -0.71604 , -0.68798 , -0.1182
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999791
# Time = 349.04 , Total calculated points = 34904
# Total Poincare points = 1 / 19
#
#
# phase = 7 , pitch = 2
# phi = 4.398 , theta = 2.887
# p = 71
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 52.68343 , 0.0 , 5.0 , -0.62307 , -0.76671 , -0.15474
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999907
# Time = 233.99 , Total calculated points = 23399
# Total Poincare points = 2 / 19
#
#
# phase = 7 , pitch = 3
# phi = 4.398 , theta = 2.76
# p = 72
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 53.51513 , 0.0 , 5.0 , -0.52002 , -0.83303 , -0.18878
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999871
# Time = 259.64 , Total calculated points = 25964
# Total Poincare points = 1 / 19
#
#
# phase = 7 , pitch = 4
# phi = 4.398 , theta = 2.633
# p = 73
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 54.17784 , 0.0 , 5.0 , -0.40856 , -0.88588 , -0.21977
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.99999999975
# Time = 412.59 , Total calculated points = 41259
# Total Poincare points = 1 / 19
#
#
# phase = 7 , pitch = 5
# phi = 4.398 , theta = 2.505
# p = 74
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 54.66086 , 0.0 , 5.0 , -0.29049 , -0.9244 , -0.2472
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999774
# Time = 387.44 , Total calculated points = 38744
# Total Poincare points = 1 / 19
#
#
# phase = 7 , pitch = 6
# phi = 4.398 , theta = 2.378
# p = 75
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 54.95636 , 0.0 , 5.0 , -0.16772 , -0.94796 , -0.27063
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999938
# Time = 220.74 , Total calculated points = 22074
# Total Poincare points = 1 / 19
#
#
# phase = 7 , pitch = 7
# phi = 4.398 , theta = 2.251
# p = 76
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 55.05956 , 0.0 , 5.0 , -0.04224 , -0.95619 , -0.28968
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.99999999993
# Time = 234.28 , Total calculated points = 23428
# Total Poincare points = 1 / 19
#
#
# phase = 7 , pitch = 8
# phi = 4.398 , theta = 2.123
# p = 77
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 54.9688 , 0.0 , 5.0 , 0.08393 , -0.94895 , -0.30405
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999856
# Time = 312.69 , Total calculated points = 31269
# Total Poincare points = 1 / 19
#
#
# phase = 7 , pitch = 9
# phi = 4.398 , theta = 1.996
# p = 78
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 54.68554 , 0.0 , 5.0 , 0.20873 , -0.92636 , -0.31349
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.99999999995
# Time = 253.44 , Total calculated points = 25344
# Total Poincare points = 1 / 19
#
#
# phase = 7 , pitch = 10
# phi = 4.398 , theta = 1.869
# p = 79
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 54.21436 , 0.0 , 5.0 , 0.33016 , -0.88879 , -0.31787
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.99999999992
# Time = 304.56 , Total calculated points = 30456
# Total Poincare points = 1 / 19
#
#
# phase = 8 , pitch = 1
# phi = 5.027 , theta = 3.014
# p = 80
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 51.74327 , 0.0 , 5.0 , -0.72104 , -0.69173 , -0.04001
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.9999999998
# Time = 336.53 , Total calculated points = 33653
# Total Poincare points = 1 / 19
#
#
# phase = 8 , pitch = 2
# phi = 5.027 , theta = 2.887
# p = 81
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 52.77681 , 0.0 , 5.0 , -0.633 , -0.77415 , 0.00038
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.99999999996
# Time = 144.77 , Total calculated points = 14477
# Total Poincare points = 2 / 19
#
#
# phase = 8 , pitch = 3
# phi = 5.027 , theta = 2.76
# p = 82
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 53.65331 , 0.0 , 5.0 , -0.53471 , -0.84405 , 0.04077
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999886
# Time = 246.07 , Total calculated points = 24607
# Total Poincare points = 1 / 19
#
#
# phase = 8 , pitch = 4
# phi = 5.027 , theta = 2.633
# p = 83
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 54.3586 , 0.0 , 5.0 , -0.42778 , -0.90029 , 0.08049
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999843
# Time = 297.1 , Total calculated points = 29710
# Total Poincare points = 1 / 19
#
#
# phase = 8 , pitch = 5
# phi = 5.027 , theta = 2.505
# p = 84
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 54.88125 , 0.0 , 5.0 , -0.31392 , -0.94197 , 0.11892
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999863
# Time = 278.64 , Total calculated points = 27864
# Total Poincare points = 1 / 19
#
#
# phase = 8 , pitch = 6
# phi = 5.027 , theta = 2.378
# p = 85
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 55.21283 , 0.0 , 5.0 , -0.19499 , -0.96841 , 0.15542
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999948
# Time = 213.63 , Total calculated points = 21363
# Total Poincare points = 1 / 19
#
#
# phase = 8 , pitch = 7
# phi = 5.027 , theta = 2.251
# p = 86
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 55.34796 , 0.0 , 5.0 , -0.0729 , -0.97919 , 0.1894
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999945
# Time = 226.45 , Total calculated points = 22645
# Total Poincare points = 1 / 19
#
#
# phase = 8 , pitch = 8
# phi = 5.027 , theta = 2.123
# p = 87
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 55.28446 , 0.0 , 5.0 , 0.05037 , -0.97413 , 0.22032
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999906
# Time = 266.34 , Total calculated points = 26634
# Total Poincare points = 1 / 19
#
#
# phase = 8 , pitch = 9
# phi = 5.027 , theta = 1.996
# p = 88
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 55.02336 , 0.0 , 5.0 , 0.17282 , -0.9533 , 0.24768
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999956
# Time = 252.21 , Total calculated points = 25221
# Total Poincare points = 1 / 19
#
#
# phase = 8 , pitch = 10
# phi = 5.027 , theta = 1.869
# p = 89
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 54.56887 , 0.0 , 5.0 , 0.29247 , -0.91706 , 0.27103
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999926
# Time = 303.03 , Total calculated points = 30303
# Total Poincare points = 1 / 19
#
#
# phase = 9 , pitch = 1
# phi = 5.655 , theta = 3.014
# p = 90
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 51.3188 , 0.0 , 5.0 , -0.75276 , -0.65788 , 0.02326
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.9999999998
# Time = 335.99 , Total calculated points = 33599
# Total Poincare points = 1 / 19
#
#
# phase = 9 , pitch = 2
# phi = 5.655 , theta = 2.887
# p = 91
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 51.93473 , 0.0 , 5.0 , -0.69592 , -0.707 , 0.12589
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999933
# Time = 195.11 , Total calculated points = 19511
# Total Poincare points = 2 / 19
#
#
# phase = 9 , pitch = 3
# phi = 5.655 , theta = 2.76
# p = 92
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 52.40725 , 0.0 , 5.0 , -0.62782 , -0.74468 , 0.22648
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999844
# Time = 289.84 , Total calculated points = 28984
# Total Poincare points = 1 / 19
#
#
# phase = 9 , pitch = 4
# phi = 5.655 , theta = 2.633
# p = 93
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 52.72871 , 0.0 , 5.0 , -0.54956 , -0.77032 , 0.32341
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999983
# Time = 81.23 , Total calculated points = 8123
# Total Poincare points = 3 / 19
#
#
# phase = 9 , pitch = 5
# phi = 5.655 , theta = 2.505
# p = 94
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 52.8939 , 0.0 , 5.0 , -0.46242 , -0.78349 , 0.41511
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999935
# Time = 208.64 , Total calculated points = 20864
# Total Poincare points = 1 / 19
#
#
# phase = 9 , pitch = 6
# phi = 5.655 , theta = 2.378
# p = 95
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 52.90016 , 0.0 , 5.0 , -0.36779 , -0.78399 , 0.50009
# Particle too far from the layer = False
# Initial energy = 1.0 , final energy = 0.999999999982
# Time = 95.61 , Total calculated points = 9561
# Total Poincare points = 3 / 19
#
#
# phase = 9 , pitch = 7
# phi = 5.655 , theta = 2.251
# p = 96
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 52.74739 , 0.0 , 5.0 , -0.26721 , -0.77181 , 0.57698
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999966
# Time = 207.08 , Total calculated points = 20708
# Total Poincare points = 1 / 19
#
#
# phase = 9 , pitch = 8
# phi = 5.655 , theta = 2.123
# p = 97
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 52.43806 , 0.0 , 5.0 , -0.16232 , -0.74714 , 0.64454
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999879
# Time = 285.71 , Total calculated points = 28571
# Total Poincare points = 1 / 19
#
#
# phase = 9 , pitch = 9
# phi = 5.655 , theta = 1.996
# p = 98
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 51.97717 , 0.0 , 5.0 , -0.05479 , -0.71039 , 0.70168
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.99999999988
# Time = 298.84 , Total calculated points = 29884
# Total Poincare points = 1 / 19
#
#
# phase = 9 , pitch = 10
# phi = 5.655 , theta = 1.869
# p = 99
# Initial approximation (x0, y0, z0, Vx0, Vy0, Vz0) = 51.37217 , 0.0 , 5.0 , 0.05362 , -0.66214 , 0.74746
# Particle too far from the layer = True
# Initial energy = 1.0 , final energy = 0.999999999913
# Time = 298.03 , Total calculated points = 29803
# Total Poincare points = 1 / 19
#
#
# Surges. Mean:  0.630511800612 . Mean of **2: 3.03622837297
# Surges Numerical. Mean:  0.505504855676 . Mean of **2: 3.0944524253

# %% [markdown]
# p = phase * (maxpitch - 1) + pitch - 1
